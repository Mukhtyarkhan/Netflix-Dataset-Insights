# %% [markdown]
# # Netflix_Movies_TV_Shows EDA
# ##### Performing Exploratory Data Analysis to understand the dataset

# %%
# Import libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load Dataset
df=pd.read_csv(r"D:\Projects\Anaylsis\Netflix Movies & TV Shows\netflix_titles.csv")

# %%
df.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.describe().T
# Out:
#                count         mean       std     min     25%     50%     75%  \
# release_year  8807.0  2014.180198  8.819312  1925.0  2013.0  2017.0  2019.0
#
#                  max
# release_year  2021.0

# %%
df.describe(include="O").T
# Out:
#             count unique                                                top  \
# show_id      8807   8807                                                 s1
# type         8807      2                                              Movie
# title        8807   8807                               Dick Johnson Is Dead
# director     6173   4528                                      Rajiv Chilaka
# cast         7982   7692                                 David Attenborough
# country      7976    748                                      United States
# date_added   8797   1767                                    January 1, 2020
# rating       8803     17                                              TV-MA
# duration     8804    220                                           1 Season
# listed_in    8807    514                       Dramas, International Movies
# description  8807   8775  Paranormal activity at a lush, abandoned prope...
#
#              freq
# show_id         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Adjust data types and fill in missing values

# %% [markdown]
# ### Update date_added to datetime and check

# %%
# cover the data type from object to datetime
df['date_added']=df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'], format='%B %d, %Y')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # Hnadling missing values
# ## rating,cast,country and director have nulls filled with 'Unavailable'

# %%
df.fillna({'rating':'unavailable','cast':'Unavaiable','country':'Unavaiable','director':'Unavaiable'},inplace=True)
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
df[df['date_added'].isnull()]
# Out:
#      show_id     type                                        title  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories
# 6174   s6175  TV Show              Anthony Bourdain: Parts Unknown
# 6795   s6796  TV Show                                      Frasier
# 6806   s6807  TV Show                                      Friends
# 6901   s6902  TV Show                              Gunslinger Girl
# 7196   s7197  TV Show                                     Kikoriki
# 7254   s7255  TV Show                          La Familia P. Luche
# 7406   s7407  TV Show                                        Maron
# 7847   s7848  TV Show                                 Red vs. Blue
# 8182   s8183  TV Show                 The Adventures of Figaro Pho
#
#         director                                               cast  \
# 6066  Unavaiable  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...
# 6174  Unavaiable                                   Anthony Bourdain
# ...

# %%
most_recent_entry_date=df['date_added'].max()
most_recent_entry_date
# Out:
# Timestamp('2021-09-25 00:00:00')

# %%
df.fillna({'date_added':most_recent_entry_date},inplace=True)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water       Unavaiable
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans       Unavaiable
# 4      s5  TV Show           Kota Factory       Unavaiable
#
#                                                 cast        country  \
# 0                                         Unavaiable  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     Unavaiable
# 3                                         Unavaiable     Unavaiable
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df[df["show_id"]=="s6175"]
# Out:
#      show_id     type                            title    director  \
# 6174   s6175  TV Show  Anthony Bourdain: Parts Unknown  Unavaiable
#
#                   cast        country date_added  release_year rating  \
# 6174  Anthony Bourdain  United States 2021-09-25          2018  TV-PG
#
#        duration   listed_in                                        description
# 6174  5 Seasons  Docuseries  This CNN original series has chef Anthony Bour...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        3
# listed_in       0
# description     0
# dtype: int64

# %%
df[df['duration'].isnull()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df[df['director']=='Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df.loc[df['director']=='Louis C.K.','duration']=df['rating']
df[df['director']=='Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min   74 min
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min   84 min
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min   66 min
#
#      listed_in                                        description
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...

# %%
df.loc[df['director']=='Louis C.K.','rating']='Unavailable'
df[df['director']=='Louis C.K.'].head()
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year       rating  \
# 5541  Louis C.K.  United States 2017-04-04          2017  Unavailable
# 5794  Louis C.K.  United States 2016-09-16          2010  Unavailable
# 5813  Louis C.K.  United States 2016-08-15          2015  Unavailable
#
#      duration listed_in                                        description
# 5541   74 min    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794   84 min    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813   66 min    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# # Visualizations
# ## Let's take a look at types of shows that has been watch on Netflix

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
counts=df['type'].value_counts()
sns.barplot(x=counts.index,y=counts.values)
plt.xlabel("Type")
plt.ylabel("Count")
plt.title('Count Vs Type of Shows')
plt.show()

# %% [markdown]
# # Country Analysis

# %%
df['country'].value_counts().to_frame()
# Out:
#                                         count
# country
# United States                            2818
# India                                     972
# Unavaiable                                831
# United Kingdom                            419
# Japan                                     245
# ...                                       ...
# Romania, Bulgaria, Hungary                  1
# Uruguay, Guatemala                          1
# France, Senegal, Belgium                    1
# Mexico, United States, Spain, Colombia      1
# United Arab Emirates, Jordan                1
#
# [749 rows x 1 columns]

# %%
country=df['country'].value_counts()
plt.figure(figsize =(14,6))
sns.countplot(x='country', order=df['country'].value_counts().index[0:10],data=df)
plt.title('Country Wise Content on Netflix')
# Out:
# Text(0.5, 1.0, 'Country Wise Content on Netflix')

# %%
plt.figure(figsize =(14,6))
sns.barplot(x=country.index[:10], y=country.values[:10])
plt.title('Country Wise Content on Netflix')
# Out:
# Text(0.5, 1.0, 'Country Wise Content on Netflix')

# %%
Movie=df[df['type']=='Movie']
Tv_Show=df[df['type']=='TV Show']
Movie=Movie['country'].value_counts()
Tv_Show=Tv_Show['country'].value_counts()

plt.figure(figsize =(14,6))
sns.barplot(x=Movie.index[:10], y=Movie.values[:10])
plt.title('Top 10 countries producing Movie in Netflix')

plt.figure(figsize =(14,6))
sns.barplot(x=Tv_Show.index[:10], y=Tv_Show.values[:10])
plt.title('Top 10 countries producing TV shows in Netflix')
# Out:
# Text(0.5, 1.0, 'Top 10 countries producing TV shows in Netflix')

# %%
content_type_counts = df['type'].value_counts()
content_type_counts.plot(kind='bar')
plt.show()

# %%
releases_per_year = df['release_year'].value_counts().sort_index()
releases_per_year.plot()
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# our summary
text = "I am a BS Software Engineering student with a passion for Data Science and Machine Learning. I have skills in Python, SQL, data analysis, data visualization, machine learning, deep learning, and NLP. I can bring value to any organization with my expertise and experience."

# Create the wordcloud object
wordcloud = WordCloud(width=280, height=280, margin=1).generate(text)

# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
